# %% [markdown]
# # Stack Plots in Matplotlib
# * Let's Start with a Pie Chart
# * Before we understand what a stack plot is, let's visualize some simple data
# * Imagine you surveyed how a group of students spends their after-school time;

# %%
import matplotlib.pyplot as plt

# %%
activities = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
time_spent = [3,2,2,5] # hours in a day basically 

colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']
plt.figure(figsize=(6,6))
plt.pie(time_spent, labels=activities, colors = colors, autopct = "%1.1f%%", startangle=90)
plt.title("After School Activities")
plt.axis('equal')
plt.show()

# %% [markdown]
# # Now. let's imaging you surveyed multiple days, and you want to track how the timespent on each activity changes iver a weak

# %%
import matplotlib.pyplot as plt 

days = [1,2,3,4,5,6,7] #  Days of a Week 
studying = [3,4,5,6,7,8,9]
playing = [1,2,3,4,5,6,7]
watching_tv = [2,4,6,8,2,4,6]
sleeping = [9,8,6,7,8,9,7]

labels = ["Studying", "Playing", "Watching_Tv", "Sleeping"]
colors = ["Blue", "Green", "Yellow", "Red"]

plt.figure(figsize=(6,6))
plt.stackplot(days, studying, playing, watching_tv, sleeping, labels = labels, colors = colors , alpha = 0.8)
plt.legend(loc = 'upper left')
plt.title("Weekly activities after school")
plt.xlabel("Days")
plt.ylabel("Activities Hours")
plt.grid(True)
plt.show()

# %% [markdown]
# # Key parameters in stackplot
# * x -- The x-axis data (like days)
# * *args -- Multiple y-values (like studying, playing, etc.)
# * labels -- Labels for the legend
# * colors -- list of colors for each stack
# * alpha -- Transparency level (o to 1)
# * loc (in legend) Position of the legend  ('upper left', 'best', etc.)
